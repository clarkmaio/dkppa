# %%
import polars as pl


pl.read_parquet('https://huggingface.co/buckets/clarkmaio/dkppa/resolve/dk_era5_2024.parquet')
# Out:
# shape: (7_914_384, 5)
# ┌─────────────────────┬──────────┬───────────┬────────────┬───────────┐
# │ time                ┆ latitude ┆ longitude ┆ u100       ┆ v100      │
# │ ---                 ┆ ---      ┆ ---       ┆ ---        ┆ ---       │
# │ datetime[ns]        ┆ f64      ┆ f64       ┆ f32        ┆ f32       │
# ╞═════════════════════╪══════════╪═══════════╪════════════╪═══════════╡
# │ 2024-01-01 00:00:00 ┆ 58.25    ┆ 3.0       ┆ -17.899261 ┆ 8.417053  │
# │ 2024-01-01 00:00:00 ┆ 58.25    ┆ 3.25      ┆ -18.834808 ┆ 7.433655  │
# │ 2024-01-01 00:00:00 ┆ 58.25    ┆ 3.5       ┆ -19.997894 ┆ 6.491272  │
# │ 2024-01-01 00:00:00 ┆ 58.25    ┆ 3.75      ┆ -21.337738 ┆ 6.036194  │
# │ 2024-01-01 00:00:00 ┆ 58.25    ┆ 4.0       ┆ -22.297699 ┆ 5.717834  │
# │ …                   ┆ …        ┆ …         ┆ …          ┆ …         │
# │ 2024-12-31 23:00:00 ┆ 54.25    ┆ 15.0      ┆ 9.984421   ┆ 11.156494 │
# │ 2024-12-31 23:00:00 ┆ 54.25    ┆ 15.25     ┆ 9.54985    ┆ 10.406494 │
# ...
